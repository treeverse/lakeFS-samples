# %% [markdown]
# <img src="./images/logo.svg" alt="lakeFS logo" width=300/>
#
# # lakeFS multiple storage backend support enables seamless data management across multiple storage systems — on-premises, across public clouds, or hybrid environments.
#
# [📚 Multiple Storage Backends Docs](https://docs.lakefs.io/latest/howto/multiple-storage-backends/)

# %% [markdown]
# ## Config
#
# **_If you're not using the provided lakeFS server and MinIO/Local storage then change these values to match your environment_**

# %% [markdown]
# ### lakeFS endpoint and credentials

# %%
lakefsEndPoint = 'http://lakefs:8000' # e.g. 'https://username.aws_region_name.lakefscloud.io' 
lakefsAccessKey = 'AKIAIOSFOLKFSSAMPLES'
lakefsSecretKey = 'wJalrXUtnFEMI/K7MDENG/bPxRfiCYEXAMPLEKEY'

# %% [markdown]
# ### Object Storage
#
# The storageNamespace in lakeFS needs to be unique per repository. The value given here will be combined with the repo name to create the storage namespace used.

# %% [markdown]
# **You shouldn't need to change anything in next cell because Local and MinIO storage is configured for lakeFS Enterprise sample, just run it**

# %%
storageIdLocal = 'local' # Storage Id for local storage which was configured in lakeFS
storageNamespaceLocal = 'local://example' # e.g. "local://folder"

storageIdMinIO = 'minio' # Storage Id for MinIO which was configured in lakeFS
storageNamespaceMinIO = 's3://example' # e.g. "s3://bucket"

# %% [markdown]
# **If you configured AWS S3, Azure Blob or GCP GCS storage then change storage namespace in following cell otherwise run as is**

# %%
storageIdS3USEast1 = 's3-us-east-1' # Storage Id for AWS S3 which was configured in lakeFS
storageNamespaceS3USEast1 = 's3://bucket-name'

storageIdS3USWest2 = 's3-us-west-2' # Storage Id for AWS S3 which was configured in lakeFS
storageNamespaceS3USWest2 = 's3://bucket-name'

storageIdS3EUWest3 = 's3-eu-west-3' # Storage Id for AWS S3 which was configured in lakeFS
storageNamespaceS3EUWest3 = 's3://bucket-name'

storageIdAzureAnalytics = 'azure-analytics' # Storage Id for Azure Blob which was configured in lakeFS
storageNamespaceAzureAnalytics = 'https://storage-account-name.blob.core.windows.net/storage-container-name'

storageIdGCSDev = 'gcs-dev' # Storage Id for GCP GCS which was configured in lakeFS
storageNamespaceGCSDev = 'gs://bucket-name'

# %% [markdown]
# ## Setup
#
# **(you shouldn't need to change anything in this section, just run it)**

# %%
repo_name_alpaca_dataset = "alpaca-dataset"
repo_name_dogs_dataset = "dogs-dataset"
repo_name_h5_dataset = "h5-dataset"
repo_name_auto_lidar_dataset = "auto-lidar-dataset"
repo_name_cellular_5g_dataset = "cellular-5g-dataset"
repo_name_morrow_plots_treatment_and_yield_dataset = "morrow-plots-treatment-and-yield-dataset"
repo_name_airbus_ship_detection_dataset = "airbus-ship-detection-dataset"
repo_name_retail_dataset = "retail-dataset"
repo_name_skin_cancer_dataset = "skin-cancer-dataset"
repo_name_users_dataset = "users-dataset"

# %% [markdown]
# ### Versioning Information

# %%
mainBranch = "main"

# %% [markdown]
# ### Import libraries

# %%
import os
import lakefs
from assets.lakefs_demo import print_commit, upload_objects

# %% [markdown]
# ### Set environment variables

# %%
os.environ["LAKECTL_SERVER_ENDPOINT_URL"] = lakefsEndPoint
os.environ["LAKECTL_CREDENTIALS_ACCESS_KEY_ID"] = lakefsAccessKey
os.environ["LAKECTL_CREDENTIALS_SECRET_ACCESS_KEY"] = lakefsSecretKey

# %% [markdown]
# #### Verify lakeFS credentials by getting lakeFS version

# %%
print("Verifying lakeFS credentials…")
try:
    v=lakefs.client.Client().version
except:
    print("🛑 failed to get lakeFS version")
else:
    print(f"…✅lakeFS credentials verified\n\nℹ️lakeFS version {v}")

# %% [markdown]
# ### Define lakeFS Repository

# %% [markdown]
# ##### Create repository in Local storage

# %%
storageId = storageIdLocal
storageNamespace = storageNamespaceLocal

# %%
repo_alpaca_dataset = lakefs.Repository(repo_name_alpaca_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_alpaca_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_alpaca_dataset)

# %% [markdown]
# ##### Create multiple repositories in MinIO storage

# %%
storageId = storageIdMinIO
storageNamespace = storageNamespaceMinIO

# %%
repo_dogs_dataset = lakefs.Repository(repo_name_dogs_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_dogs_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_dogs_dataset)

# %%
repo_h5_dataset = lakefs.Repository(repo_name_h5_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_h5_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_h5_dataset)

# %%
repo_auto_lidar_dataset = lakefs.Repository(repo_name_auto_lidar_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_auto_lidar_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_auto_lidar_dataset)

# %%
repo_cellular_5g_dataset = lakefs.Repository(repo_name_cellular_5g_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_cellular_5g_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_cellular_5g_dataset)

# %% [markdown]
# ##### Create repository in AWS S3 storage in us-east-1 region. **If you didn't configure S3 storage in us-east-1 region then the repo will be created in MinIO by default.**

# %%
#If you configured S3 storage in us-east-1 region then uncomment following 2 lines in this cell
#storageId = storageIdS3USEast1
#storageNamespace = storageNamespaceS3USEast1

# %%
repo_morrow_plots_treatment_and_yield_dataset = lakefs.Repository(repo_name_morrow_plots_treatment_and_yield_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_morrow_plots_treatment_and_yield_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_morrow_plots_treatment_and_yield_dataset)

# %% [markdown]
# ##### Create repository in AWS S3 storage in us-west-2 region. **If you didn't configure S3 storage in us-west-2 region then the repo will be created in MinIO by default.**

# %%
#If you configured S3 storage in us-west-2 region then uncomment following 2 lines in this cell
#storageId = storageIdS3USWest2
#storageNamespace = storageNamespaceS3USWest2

# %%
repo_airbus_ship_detection_dataset = lakefs.Repository(repo_name_airbus_ship_detection_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_airbus_ship_detection_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_airbus_ship_detection_dataset)

# %% [markdown]
# ##### Create repository in AWS S3 storage in eu-west-3 region. **If you didn't configure S3 storage in eu-west-3 region then the repo will be created in MinIO by default.**

# %%
#If you configured S3 storage in eu-west-3 region then uncomment following 2 lines in this cell
#storageId = storageIdS3EUWest3
#storageNamespace = storageNamespaceS3EUWest3

# %%
repo_retail_dataset = lakefs.Repository(repo_name_retail_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_retail_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_retail_dataset)

# %% [markdown]
# ##### Create repository in Azure Blob storage. **If you didn't configure Azure Blob storage then the repo will be created in MinIO by default.**

# %%
#If you configured Azure Blob storage then uncomment following 2 lines in this cell
#storageId = storageIdAzureAnalytics
#storageNamespace = storageNamespaceAzureAnalytics

# %%
repo_skin_cancer_dataset = lakefs.Repository(repo_name_skin_cancer_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_skin_cancer_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_skin_cancer_dataset)

# %% [markdown]
# ##### Create repository in GCP GCS storage. **If you didn't configure GCP GCS storage then the repo will be created in MinIO by default.**

# %%
#If you configured GCP GCS storage then uncomment following 2 lines in this cell
#storageId = storageIdGCSDev
#storageNamespace = storageNamespaceGCSDev

# %%
repo_users_dataset = lakefs.Repository(repo_name_users_dataset).create(storage_namespace=f"{storageNamespace}/{repo_name_users_dataset}", storage_id=storageId, default_branch=mainBranch, exist_ok=True)
print(repo_users_dataset)

# %% [markdown]
# ## Upload data

# %%
repoAlpacaDatasetBranchMain = repo_alpaca_dataset.branch(mainBranch)
upload_objects(repoAlpacaDatasetBranchMain, '/data/alpaca_training_imgs')
ref = repoAlpacaDatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %%
repoDogsDatasetBranchMain = repo_dogs_dataset.branch(mainBranch)
upload_objects(repoDogsDatasetBranchMain, '/data/stanfordogsdataset')
ref = repoDogsDatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %%
repoH5DatasetBranchMain = repo_h5_dataset.branch(mainBranch)
upload_objects(repoH5DatasetBranchMain, '/data/h5_data')
ref = repoH5DatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %%
repoAutoLidarDatasetBranchMain = repo_auto_lidar_dataset.branch(mainBranch)
upload_objects(repoAutoLidarDatasetBranchMain, '/data/auto_lidar_data')
ref = repoAutoLidarDatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %%
repoCellular5gDatasetBranchMain = repo_cellular_5g_dataset.branch(mainBranch)
upload_objects(repoCellular5gDatasetBranchMain, '/data/cellular_5g_data')
ref = repoCellular5gDatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %%
repoMorrowPlotsTreatmentAndYieldDatasetBranchMain = repo_morrow_plots_treatment_and_yield_dataset.branch(mainBranch)
upload_objects(repoMorrowPlotsTreatmentAndYieldDatasetBranchMain, '/data/DOI-10-13012-b2idb-7865141_v1')
ref = repoMorrowPlotsTreatmentAndYieldDatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %%
repoAirbusShipDetectionDatasetBranchMain = repo_airbus_ship_detection_dataset.branch(mainBranch)
upload_objects(repoAirbusShipDetectionDatasetBranchMain, '/data/airbus-ship-detection')
ref = repoAirbusShipDetectionDatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %%
repoRetailDatasetBranchMain = repo_retail_dataset.branch(mainBranch)
upload_objects(repoRetailDatasetBranchMain, '/data/OrionStar')
ref = repoRetailDatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %%
repoSkinCancerDatasetBranchMain = repo_skin_cancer_dataset.branch(mainBranch)
upload_objects(repoSkinCancerDatasetBranchMain, '/data/skin_cancer')
ref = repoSkinCancerDatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %%
repoUsersDatasetBranchMain = repo_users_dataset.branch(mainBranch)
upload_objects(repoUsersDatasetBranchMain, '/data/userdata')
ref = repoUsersDatasetBranchMain.commit(message='Uploaded data', metadata={'using': 'python_sdk'})
print_commit(ref.get_commit())

# %% [markdown]
# ## More Questions?
#
# **👉🏻 Join the lakeFS Slack group - https://lakefs.io/slack**
